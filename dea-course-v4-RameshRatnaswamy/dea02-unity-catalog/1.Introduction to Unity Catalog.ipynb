-- %% [markdown]
-- ### Check whether the workspace is attached to a Unity Catalog Metastore

-- %%
-- There is no SQL command to navigate to the environment panel in Databricks.
SELECT current_metastore();
